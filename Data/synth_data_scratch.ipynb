# %%
import distributions as d
import matplotlib.pyplot as plt

# %%
globalDefect = d.sample_beta(2,100, 1000)

plt.hist(globalDefect, bins='auto')
# Out:
# (array([ 51., 101., 131., 117., 119., 104.,  69.,  59.,  45.,  62.,  30.,
#          28.,  16.,  19.,  11.,  11.,   7.,   7.,   2.,   0.,   2.,   2.,
#           2.,   3.,   0.,   0.,   2.]),
#  array([0.00021629, 0.00353313, 0.00684998, 0.01016682, 0.01348367,
#         0.01680052, 0.02011736, 0.02343421, 0.02675105, 0.0300679 ,
#         0.03338474, 0.03670159, 0.04001844, 0.04333528, 0.04665213,
#         0.04996897, 0.05328582, 0.05660266, 0.05991951, 0.06323635,
#         0.0665532 , 0.06987005, 0.07318689, 0.07650374, 0.07982058,
#         0.08313743, 0.08645427, 0.08977112]),
#  <BarContainer object of 27 artists>)

# %%
alpha, beta = d.beta_from_mean_var(.05, .005)
print(alpha, beta)
aisleDefect = d.sample_beta(alpha, beta, 100)

plt.hist(aisleDefect, bins='auto')
# Out:
# 0.42500000000000004 8.075
# (array([52., 15., 11.,  5.,  7.,  3.,  1.,  2.,  0.,  1.,  1.,  1.,  1.]),
#  array([1.34308585e-10, 2.49778624e-02, 4.99557247e-02, 7.49335869e-02,
#         9.99114492e-02, 1.24889311e-01, 1.49867174e-01, 1.74845036e-01,
#         1.99822898e-01, 2.24800760e-01, 2.49778623e-01, 2.74756485e-01,
#         2.99734347e-01, 3.24712210e-01]),
#  <BarContainer object of 13 artists>)

# %%
pickEvents = d.sample_poisson(20, 1000)
plt.hist(pickEvents, bins='auto')
# Out:
# (array([  7.,   7.,  12.,  12.,  29.,  79.,  55.,  83.,  93.,  79.,  82.,
#         166.,  66.,  74.,  52.,  32.,  43.,   9.,  10.,   1.,   4.,   5.]),
#  array([ 8.        ,  9.18181818, 10.36363636, 11.54545455, 12.72727273,
#         13.90909091, 15.09090909, 16.27272727, 17.45454545, 18.63636364,
#         19.81818182, 21.        , 22.18181818, 23.36363636, 24.54545455,
#         25.72727273, 26.90909091, 28.09090909, 29.27272727, 30.45454545,
#         31.63636364, 32.81818182, 34.        ]),
#  <BarContainer object of 22 artists>)

# %%
timeInLoc = d.sample_negative_binomial(9, .35, 1000)
plt.hist(timeInLoc, bins='auto')
# Out:
# (array([  5.,  26.,  62.,  80.,  63., 122., 124., 117.,  52.,  85.,  78.,
#          55.,  25.,  31.,  26.,  14.,  16.,   4.,   6.,   4.,   1.,   0.,
#           1.,   1.,   1.,   1.]),
#  array([ 3.        ,  4.76923077,  6.53846154,  8.30769231, 10.07692308,
#         11.84615385, 13.61538462, 15.38461538, 17.15384615, 18.92307692,
#         20.69230769, 22.46153846, 24.23076923, 26.        , 27.76923077,
#         29.53846154, 31.30769231, 33.07692308, 34.84615385, 36.61538462,
#         38.38461538, 40.15384615, 41.92307692, 43.69230769, 45.46153846,
#         47.23076923, 49.        ]),
#  <BarContainer object of 26 artists>)

# %%
maxVolume = d.sample_poisson(25, 1000)
plt.hist(maxVolume, bins='auto')
# Out:
# (array([  5.,   5.,  18.,  13.,  23.,  83.,  40., 143.,  85.,  68., 150.,
#          64., 132.,  42.,  39.,  44.,  11.,  21.,   2.,   6.,   3.,   1.,
#           2.]),
#  array([11.        , 12.39130435, 13.7826087 , 15.17391304, 16.56521739,
#         17.95652174, 19.34782609, 20.73913043, 22.13043478, 23.52173913,
#         24.91304348, 26.30434783, 27.69565217, 29.08695652, 30.47826087,
#         31.86956522, 33.26086957, 34.65217391, 36.04347826, 37.43478261,
#         38.82608696, 40.2173913 , 41.60869565, 43.        ]),
#  <BarContainer object of 23 artists>)

# %%
absVolDiff = d.sample_normal(0, 1000, 1000)
plt.hist(absVolDiff, bins='auto')
# Out:
# (array([  1.,   4.,   1.,   5.,  15.,  27.,  30.,  36.,  39.,  71.,  81.,
#          91., 112., 112.,  89.,  85.,  59.,  35.,  46.,  31.,   9.,  10.,
#           6.,   1.,   4.]),
#  array([-3189.25684953, -2939.0886305 , -2688.92041146, -2438.75219242,
#         -2188.58397338, -1938.41575435, -1688.24753531, -1438.07931627,
#         -1187.91109723,  -937.7428782 ,  -687.57465916,  -437.40644012,
#          -187.23822108,    62.92999795,   313.09821699,   563.26643603,
#           813.43465507,  1063.6028741 ,  1313.77109314,  1563.93931218,
#          1814.10753122,  2064.27575025,  2314.44396929,  2564.61218833,
#          2814.78040737,  3064.9486264 ]),
#  <BarContainer object of 25 artists>)

# %%
currentVolume = d.sample_normal(2160, 600, 1000)      
plt.hist(currentVolume, bins='auto')
# Out:
# (array([  2.,   3.,   5.,   5.,  17.,  31.,  45.,  47.,  68.,  79., 112.,
#         105.,  88.,  86.,  93.,  73.,  47.,  41.,  26.,  14.,   9.,   2.,
#           0.,   0.,   1.,   1.]),
#  array([ 299.32027719,  455.09929993,  610.87832268,  766.65734542,
#          922.43636816, 1078.21539091, 1233.99441365, 1389.77343639,
#         1545.55245913, 1701.33148188, 1857.11050462, 2012.88952736,
#         2168.66855011, 2324.44757285, 2480.22659559, 2636.00561834,
#         2791.78464108, 2947.56366382, 3103.34268657, 3259.12170931,
#         3414.90073205, 3570.6797548 , 3726.45877754, 3882.23780028,
#         4038.01682302, 4193.79584577, 4349.57486851]),
#  <BarContainer object of 26 artists>)
